# %%
import os
import os.path as osp
import sys
import time

# %%
from data import *
from utils.augmentations import SSDAugmentation
from layers.modules import MultiBoxLoss
from ssd import build_ssd

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import torchvision as tv
import torch.optim as optim

# %%
import torch.utils.data as data
import torchvision.datasets

import numpy as np
from PIL import Image
import argparse

from matplotlib import pyplot as plt
import pandas as pd
import cv2 
import pickle as pkl
import random
import tarfile
import collections
import math
import datetime
import pickle

# %%
from config_vgg16_ssd import *
import xml.etree.ElementTree as ET

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
def xavier(param):
    nn.init.xavier_uniform(param)


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        xavier(m.weight.data)
        m.bias.data.zero_()

# %%
def train(device, resume=None , momentum= .9):
    
    #use voc config 
    cfg = voc
 
    ssd_net = build_ssd('train', cfg['min_dim'], cfg['num_classes'])
    dataset = VOCDetection(root=dataset_root, image_sets=[('2012', 'train')],
                            transform=SSDAugmentation(cfg['min_dim'],
                             MEANS))
 

    if resume:
        print('Resuming training, loading previous training at ',resume)
        ssd_net.load_weights(resume) 
    else:
        vgg_weights = torch.load(basenet)
        print('Loading base network...')
        ssd_net.vgg.load_state_dict(vgg_weights)
        print('Initializing weights...')
        ssd_net.extras.apply(weights_init)
        ssd_net.loc.apply(weights_init)
        ssd_net.conf.apply(weights_init)
    
    net = ssd_net
    
    if device:
        net = torch.nn.DataParallel(ssd_net)
        torch.backends.cudnn.benchmark = True
        net = net.to(device)
 
    optimizer = optim.SGD(net.parameters(), lr , momentum,weight_decay)  
    
    criterion = MultiBoxLoss(cfg['num_classes'], 0.5, True, 0, True, 3, 0.5,
                             False, torch.cuda.is_available())

    
    net.train()
    mode = 'train'
    

    loc_loss = 0
    conf_loss = 0
    epoch = 0
    print('Loading the dataset...')

    epoch_size = len(dataset) // batch_size
    print('Training SSD on: ',mode)

    step_index = 0

    #based on adapted code
    train_data_loader = data.DataLoader(dataset, batch_size=32, num_workers=4, shuffle=True,\
                               collate_fn=detection_collate,pin_memory=True)
    
    print("Images in the training set = " + str(len(dataset)))
    print("Images in a mini-batch = "+str(batch_size))
    print("mini-batches = " + str(len(train_data_loader)))
    
    
     # create batch iterator
    batch_iterator = iter(train_data_loader)
    print("STARTING - ITERATIONS")
    
    
    l_loss = []
    c_loss = []
    itr = []
    
    #for 10000 iterations - takes long
    for iteration in range(0, 1002):
        
        if iteration != 0 and (iteration % epoch_size == 0):
            # reset epoch loss counters
            loc_loss = 0
            conf_loss = 0
            epoch += 1

        if iteration in cfg['lr_steps']:
            step_index += 1
            lr_dec = lr * (gamma ** (step_index))
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_dec

            
        ## load train data
        try:
            images, targets = next(batch_iterator)
        except StopIteration:
            batch_iterator = iter(train_data_loader)
            images, targets = next(batch_iterator)


        
        if device:
            images = images.cuda()
            targets = [ann.cuda() for ann in targets]
        else:
            images = images
            targets = [ann for ann in targets]
        
        # forward
        t0 = time.time()
        out = net(images)

        # backprop
        optimizer.zero_grad()

        loss_l, loss_c = criterion(out, targets)
        loss = loss_l + loss_c

        loss.backward()

        optimizer.step()

        l_loss.append(loss_l.data.item())
        c_loss.append(loss_c.data.item())
        
        t1 = time.time()
        loc_loss += loss_l.data.item()
        conf_loss += loss_c.data.item()
        
        itr.append(iteration)
        
        if iteration % 10 == 0:
            print('timer: %.4f sec.' % (t1 - t0))
            print('iter ' + repr(iteration) + ' || Loss: %.4f ||' % (loss.data.item()), end=' ')
            currentDT = datetime.datetime.now()
            print (currentDT.strftime("%H:%M:%S %p"))
            print("\n")
        
        
        if iteration != 0 and iteration % 500 == 0:
            print('Saving state, iter:', iteration)
            iter_name = math.ceil(iteration/100)*100
            torch.save(ssd_net.state_dict(), 'trained_weights/ssd_VOC_momentum'+str(momentum)+'_' +repr(iter_name) + '.pth')
            with open('trained_weights/vgg16_ssd_stats_momentum'+str(momentum)+'.pkl','wb') as f:
                pkl.dump([l_loss, c_loss, itr], f)
                

    torch.save(ssd_net.state_dict(),
               save_folder + data_set + '.pth')

# %% [markdown]
# ###

# %%
# !cat config_vgg16_ssd.py
# Out:
# #Initialize pointers
# data_set = 'VOC'
# dataset_root = voc_root = '//datasets/ee285f-public/PascalVOC2012/'
# save_folder = 'trained_weights/'
# eval_save_folder = 'eval/'
# devkit_path = 'devkit_path/'
# output_dir = "out/"
#
# #Run related metaparameters
#
# batch_size = 32
# resume = None
#
# #Optimization metaparameters
# lr = 1e-3
# momentum = 0.9
# weight_decay = 5e-4
# gamma = 0.1
#
# confidence_threshold = 0.01
# top_k = 5
# cleanup = True
#
# YEAR = '2012'
# dataset_mean = (104, 117, 123)
# set_type = 'train'
#
# # Please Change if required
# trained_model = 'weights/ssd_pretrained.pth'
# basenet = 'weights/vgg16_reducedfc.pth'

# %%
momentum = 0.9
train(device, resume, momentum)
# Out:
# change log in ssd.py
# Loading base network...
# Initializing weights...
# Loading the dataset...
# Training SSD on:  train
# Images in the training set = 5717
# Images in a mini-batch = 32
# mini-batches = 179
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# STARTING - ITERATIONS
# timer: 13.2860 sec.
# iter 0 || Loss: 26.1474 || 00:24:55 AM
#
#
# timer: 0.8929 sec.
# iter 10 || Loss: 15.5935 || 00:25:04 AM
#
#
# timer: 0.8887 sec.
# iter 20 || Loss: 14.9956 || 00:25:23 AM
#
#
# timer: 0.8958 sec.
# iter 30 || Loss: 16.0258 || 00:25:43 AM
#
#
# timer: 1.0916 sec.
# iter 40 || Loss: 39.6013 || 00:26:04 AM
#
#
# timer: 0.8946 sec.
# iter 50 || Loss: 13.3822 || 00:26:22 AM
#
#
# timer: 1.1778 sec.
# iter 60 || Loss: 11.6438 || 00:26:43 AM
#
#
# timer: 0.9953 sec.
# iter 70 || Loss: 14.2956 || 00:27:00 AM
#
#
# timer: 0.9021 sec.
# iter 80 || Loss: 14.8794 || 00:27:20 AM
#
#
# timer: 0.9973 sec.
# iter 90 || Loss: 10.4346 || 00:27:42 AM
#
#
# timer: 0.9800 sec.
# iter 100 || Loss: 10.9056 || 00:28:01 AM
#
#
# Saving state, iter: 100
# timer: 0.9880 sec.
# iter 110 || Loss: 9.0244 || 00:28:22 AM
#
#
# timer: 1.0936 sec.
# iter 120 || Loss: 9.9401 || 00:28:43 AM
#
#
# timer: 0.7940 sec.
# iter 130 || Loss: 8.7691 || 00:29:06 AM
#
#
# timer: 1.5000 sec.
# iter 140 || Loss: 8.9970 || 00:29:24 AM
#
#
# timer: 1.2101 sec.
# iter 150 || Loss: 8.8066 || 00:29:45 AM
#
#
# timer: 1.1960 sec.
# iter 160 || Loss: 15.4725 || 00:30:04 AM
#
#
# timer: 0.6948 sec.
# iter 170 || Loss: 10.7447 || 00:30:25 AM
#
#
# timer: 0.8919 sec.
# iter 180 || Loss: 8.3978 || 00:30:50 AM
#
#
# timer: 0.9783 sec.
# iter 190 || Loss: 8.8475 || 00:31:07 AM
#
#
# timer: 0.9907 sec.
# iter 200 || Loss: 10.6720 || 00:31:29 AM
#
#
# Saving state, iter: 200
# timer: 1.1122 sec.
# iter 210 || Loss: 9.0716 || 00:31:48 AM
#
#
# timer: 0.9705 sec.
# iter 220 || Loss: 8.8631 || 00:32:09 AM
#
#
# timer: 0.8181 sec.
# iter 230 || Loss: 9.9478 || 00:32:27 AM
#
#
# timer: 0.8956 sec.
# iter 240 || Loss: 9.8174 || 00:32:47 AM
#
#
# timer: 1.0988 sec.
# iter 250 || Loss: 14.8305 || 00:33:04 AM
#
#
# timer: 0.9949 sec.
# iter 260 || Loss: 11.5004 || 00:33:25 AM
#
#
# timer: 1.0860 sec.
# iter 270 || Loss: 10.6595 || 00:33:41 AM
#
#
# timer: 0.7962 sec.
# iter 280 || Loss: 8.8215 || 00:34:02 AM
#
#
# timer: 0.9956 sec.
# iter 290 || Loss: 11.0177 || 00:34:19 AM
#
#
# timer: 0.9959 sec.
# iter 300 || Loss: 9.9112 || 00:34:40 AM
#
#
# Saving state, iter: 300
# timer: 0.9951 sec.
# iter 310 || Loss: 8.9191 || 00:34:55 AM
#
#
# timer: 0.8958 sec.
# iter 320 || Loss: 10.0368 || 00:35:18 AM
#
#
# timer: 0.6964 sec.
# iter 330 || Loss: 9.9234 || 00:35:35 AM
#
#
# timer: 0.9474 sec.
# iter 340 || Loss: 9.1397 || 00:35:54 AM
#
#
# timer: 0.9838 sec.
# iter 350 || Loss: 8.7062 || 00:36:12 AM
#
#
# timer: 0.8960 sec.
# iter 360 || Loss: 9.3498 || 00:36:33 AM
#
#
# timer: 1.2680 sec.
# iter 370 || Loss: 9.4538 || 00:36:53 AM
#
#
# timer: 0.8952 sec.
# iter 380 || Loss: 9.2055 || 00:37:10 AM
#
#
# timer: 1.0795 sec.
# iter 390 || Loss: 9.3562 || 00:37:33 AM
#
#
# timer: 0.9948 sec.
# iter 400 || Loss: 9.1899 || 00:37:50 AM
#
#
# Saving state, iter: 400
# timer: 0.9662 sec.
# iter 410 || Loss: 12.0701 || 00:38:09 AM
#
#
# timer: 0.8968 sec.
# iter 420 || Loss: 8.2995 || 00:38:27 AM
#
#
# timer: 1.0098 sec.
# iter 430 || Loss: 9.5422 || 00:38:48 AM
#
#
# timer: 0.9871 sec.
# iter 440 || Loss: 13.5080 || 00:39:04 AM
#
#
# timer: 0.9953 sec.
# iter 450 || Loss: 11.4702 || 00:39:24 AM
#
#
# timer: 0.9786 sec.
# iter 460 || Loss: 9.3271 || 00:39:42 AM
#
#
# timer: 0.8927 sec.
# iter 470 || Loss: 9.1910 || 00:40:03 AM
#
#
# timer: 1.0186 sec.
# iter 480 || Loss: 11.6369 || 00:40:23 AM
#
#
# timer: 0.7950 sec.
# iter 490 || Loss: 8.9040 || 00:40:45 AM
#
#
# timer: 0.9998 sec.
# iter 500 || Loss: 9.2235 || 00:41:04 AM
#
#
# Saving state, iter: 500
# timer: 1.0001 sec.
# iter 510 || Loss: 9.9044 || 00:41:24 AM
#
#
# timer: 0.9955 sec.
# iter 520 || Loss: 7.9145 || 00:41:41 AM
#
#
# timer: 0.8197 sec.
# iter 530 || Loss: 9.7742 || 00:42:05 AM
#
#
# timer: 0.9955 sec.
# iter 540 || Loss: 11.5320 || 00:42:22 AM
#
#
# timer: 0.8950 sec.
# iter 550 || Loss: 9.0927 || 00:42:42 AM
#
#
# timer: 0.8992 sec.
# iter 560 || Loss: 10.8524 || 00:42:59 AM
#
#
# timer: 0.9797 sec.
# iter 570 || Loss: 8.7187 || 00:43:22 AM
#
#
# timer: 0.8950 sec.
# iter 580 || Loss: 8.7677 || 00:43:39 AM
#
#
# timer: 0.9953 sec.
# iter 590 || Loss: 9.1501 || 00:44:00 AM
#
#
# timer: 0.9652 sec.
# iter 600 || Loss: 11.4782 || 00:44:18 AM
#
#
# Saving state, iter: 600
# timer: 1.0962 sec.
# iter 610 || Loss: 9.6084 || 00:44:39 AM
#
#
# timer: 0.8956 sec.
# iter 620 || Loss: 8.2571 || 00:44:58 AM
#
#
# timer: 1.0832 sec.
# iter 630 || Loss: 10.0255 || 00:45:21 AM
#
#
# timer: 0.9032 sec.
# iter 640 || Loss: 9.6570 || 00:45:38 AM
#
#
# timer: 1.2990 sec.
# iter 650 || Loss: 9.2881 || 00:46:06 AM
#
#
# timer: 0.9968 sec.
# iter 660 || Loss: 9.1970 || 00:46:26 AM
#
#
# timer: 1.3779 sec.
# iter 670 || Loss: 8.0171 || 00:46:52 AM
#
#
# timer: 1.0955 sec.
# iter 680 || Loss: 8.9890 || 00:47:14 AM
#
#
# timer: 1.3100 sec.
# iter 690 || Loss: 9.3177 || 00:47:41 AM
#
#
# timer: 1.2959 sec.
# iter 700 || Loss: 8.2420 || 00:48:05 AM
#
#
# Saving state, iter: 700
# timer: 0.8839 sec.
# iter 710 || Loss: 8.3078 || 00:48:30 AM
#
#
# timer: 1.0093 sec.
# iter 720 || Loss: 10.6646 || 00:48:55 AM
#
#
# timer: 1.1946 sec.
# iter 730 || Loss: 8.8845 || 00:49:18 AM
#
#
# timer: 1.0745 sec.
# iter 740 || Loss: 12.4566 || 00:49:44 AM
#
#
# timer: 1.2150 sec.
# iter 750 || Loss: 12.1041 || 00:50:06 AM
#
#
# timer: 1.5955 sec.
# iter 760 || Loss: 12.1744 || 00:50:33 AM
#
#
# timer: 1.2952 sec.
# iter 770 || Loss: 8.7461 || 00:50:55 AM
#
#
# timer: 1.4095 sec.
# iter 780 || Loss: 7.7713 || 00:51:21 AM
#
#
# timer: 1.1952 sec.
# iter 790 || Loss: 10.3379 || 00:51:45 AM
#
#
# timer: 1.4030 sec.
# iter 800 || Loss: 7.6271 || 00:52:13 AM
#
#
# Saving state, iter: 800
# timer: 1.3996 sec.
# iter 810 || Loss: 12.6176 || 00:52:35 AM
#
#
# timer: 1.6914 sec.
# iter 820 || Loss: 10.4028 || 00:53:02 AM
#
#
# timer: 1.2127 sec.
# iter 830 || Loss: 11.0412 || 00:53:25 AM
#
#
# timer: 1.1958 sec.
# iter 840 || Loss: 8.9513 || 00:53:54 AM
#
#
# timer: 1.3955 sec.
# iter 850 || Loss: 8.1316 || 00:54:18 AM
#
#
# timer: 1.2540 sec.
# iter 860 || Loss: 8.0107 || 00:54:43 AM
#
#
# timer: 1.2030 sec.
# iter 870 || Loss: 8.4051 || 00:55:12 AM
#
#
# timer: 1.0943 sec.
# iter 880 || Loss: 9.2836 || 00:55:35 AM
#
#
# timer: 0.6961 sec.
# iter 890 || Loss: 8.7397 || 00:56:00 AM
#
#
# timer: 1.2046 sec.
# iter 900 || Loss: 8.8472 || 00:56:25 AM
#
#
# Saving state, iter: 900
# timer: 1.4951 sec.
# iter 910 || Loss: 7.8237 || 00:56:50 AM
#
#
# timer: 0.9952 sec.
# iter 920 || Loss: 8.2883 || 00:57:16 AM
#
#
# timer: 1.2916 sec.
# iter 930 || Loss: 7.7794 || 00:57:42 AM
#
#
# timer: 0.9972 sec.
# iter 940 || Loss: 10.1517 || 00:58:09 AM
#
#
# timer: 0.8941 sec.
# iter 950 || Loss: 7.1723 || 00:58:31 AM
#
#
# timer: 0.7948 sec.
# iter 960 || Loss: 7.9143 || 00:58:57 AM
#
#
# timer: 0.9956 sec.
# iter 970 || Loss: 8.5471 || 00:59:27 AM
#
#
# timer: 1.3956 sec.
# iter 980 || Loss: 10.8916 || 00:59:48 AM
#
#
# timer: 1.0947 sec.
# iter 990 || Loss: 11.5488 || 01:00:14 AM
#
#
# timer: 1.2957 sec.
# iter 1000 || Loss: 8.7749 || 01:00:35 AM
#
#
# Saving state, iter: 1000
# timer: 1.2828 sec.
# iter 1010 || Loss: 9.7080 || 01:01:02 AM
#
#
# timer: 1.3912 sec.
# iter 1020 || Loss: 10.2997 || 01:01:26 AM
#
#
# timer: 1.2908 sec.
# iter 1030 || Loss: 9.8296 || 01:01:52 AM
#
#
# timer: 1.1836 sec.
# iter 1040 || Loss: 8.8282 || 01:02:19 AM
#
#
# timer: 1.2891 sec.
# iter 1050 || Loss: 10.4263 || 01:02:43 AM
#
#
# timer: 1.1979 sec.
# iter 1060 || Loss: 10.3956 || 01:03:12 AM
#
#
# timer: 0.7079 sec.
# iter 1070 || Loss: 9.0088 || 01:03:36 AM
#
#
# timer: 1.1993 sec.
# iter 1080 || Loss: 8.0773 || 01:04:04 AM
#
#
# timer: 1.1862 sec.
# iter 1090 || Loss: 8.2710 || 01:04:30 AM
#
#
# timer: 1.5015 sec.
# iter 1100 || Loss: 8.9397 || 01:04:53 AM
#
#
# Saving state, iter: 1100
# timer: 1.1873 sec.
# iter 1110 || Loss: 12.8306 || 01:05:19 AM
#
#
# timer: 1.7869 sec.
# iter 1120 || Loss: 7.3185 || 01:05:48 AM
#
#
# timer: 1.1955 sec.
# iter 1130 || Loss: 11.8383 || 01:06:10 AM
#
#
# timer: 0.9795 sec.
# iter 1140 || Loss: 10.2111 || 01:06:39 AM
#
#
# timer: 1.2954 sec.
# iter 1150 || Loss: 8.6415 || 01:07:01 AM
#
#
# timer: 1.1310 sec.
# iter 1160 || Loss: 10.3811 || 01:07:29 AM
#
#
# timer: 1.3952 sec.
# iter 1170 || Loss: 7.6958 || 01:07:53 AM
#
#
# timer: 1.2176 sec.
# iter 1180 || Loss: 10.5642 || 01:08:22 AM
#
#
# timer: 1.0956 sec.
# iter 1190 || Loss: 8.6593 || 01:08:43 AM
#
#
# timer: 1.3851 sec.
# iter 1200 || Loss: 10.5036 || 01:09:14 AM
#
#
# Saving state, iter: 1200
# timer: 0.8948 sec.
# iter 1210 || Loss: 7.8095 || 01:09:33 AM
#
#
# timer: 1.1928 sec.
# iter 1220 || Loss: 9.9902 || 01:10:02 AM
#
#
# timer: 1.1921 sec.
# iter 1230 || Loss: 8.3677 || 01:10:26 AM
#
#
# timer: 1.1738 sec.
# iter 1240 || Loss: 8.5691 || 01:10:54 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b716967b49e5> in <module>
#       1 momentum = 0.9
# ----> 2 train(device, resume, momentum)
#
# <ipython-input-9-38c9a1adf9a6> in train(device, resume, momentum)
#      85         ## load train data
#      86         try:
# ---> 87             images, targets = next(batch_iterator)
#      88         except StopIteration:
#      89             batch_iterator = iter(train_data_loader)
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self._pin_memory:
#     760             while self._pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# /opt/conda/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# # 1000 iter

# %%
with open('trained_weights/vgg16_ssd_stats_momentum'+str(momentum)+'.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)
plt.plot(itr,l_loss+c_loss)
plt.title('Loss - Iterations: lr=1e-3  SGD with momentum'+str(momentum)+ ' Optimizer')
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
momentum = 0.1
train(device, resume, momentum)
# Out:
# change log in ssd.py
# Loading base network...
# Initializing weights...
# Loading the dataset...
# Training SSD on:  train
# Images in the training set = 5717
# Images in a mini-batch = 32
# mini-batches = 179
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# STARTING - ITERATIONS
# timer: 2.0688 sec.
# iter 0 || Loss: 25.2260 || 01:12:40 AM
#
#
# timer: 1.1927 sec.
# iter 10 || Loss: 15.2505 || 01:13:03 AM
#
#
# timer: 1.1820 sec.
# iter 20 || Loss: 15.0488 || 01:13:31 AM
#
#
# timer: 1.1963 sec.
# iter 30 || Loss: 14.7621 || 01:13:54 AM
#
#
# timer: 1.3942 sec.
# iter 40 || Loss: 14.4945 || 01:14:22 AM
#
#
# timer: 1.2931 sec.
# iter 50 || Loss: 13.6994 || 01:14:45 AM
#
#
# timer: 1.2914 sec.
# iter 60 || Loss: 12.9553 || 01:15:13 AM
#
#
# timer: 0.9956 sec.
# iter 70 || Loss: 11.9325 || 01:15:35 AM
#
#
# timer: 1.1950 sec.
# iter 80 || Loss: 12.3056 || 01:16:01 AM
#
#
# timer: 1.4888 sec.
# iter 90 || Loss: 10.7189 || 01:16:28 AM
#
#
# timer: 1.0834 sec.
# iter 100 || Loss: 10.4685 || 01:16:51 AM
#
#
# Saving state, iter: 100
# timer: 1.0229 sec.
# iter 110 || Loss: 9.9500 || 01:17:18 AM
#
#
# timer: 1.2871 sec.
# iter 120 || Loss: 8.8925 || 01:17:43 AM
#
#
# timer: 1.2952 sec.
# iter 130 || Loss: 9.3189 || 01:18:09 AM
#
#
# timer: 1.3028 sec.
# iter 140 || Loss: 9.0570 || 01:18:34 AM
#
#
# timer: 1.1990 sec.
# iter 150 || Loss: 8.6961 || 01:19:03 AM
#
#
# timer: 1.6941 sec.
# iter 160 || Loss: 8.6013 || 01:19:28 AM
#
#
# timer: 0.8001 sec.
# iter 170 || Loss: 8.3084 || 01:19:56 AM
#
#
# timer: 0.9967 sec.
# iter 180 || Loss: 8.2589 || 01:20:16 AM
#
#
# timer: 1.2949 sec.
# iter 190 || Loss: 8.1346 || 01:20:37 AM
#
#
# timer: 1.0982 sec.
# iter 200 || Loss: 8.4004 || 01:21:11 AM
#
#
# Saving state, iter: 200
# timer: 1.1951 sec.
# iter 210 || Loss: 8.0509 || 01:21:36 AM
#
#
# timer: 1.0982 sec.
# iter 220 || Loss: 7.9709 || 01:22:02 AM
#
#
# timer: 1.0967 sec.
# iter 230 || Loss: 8.3603 || 01:22:26 AM
#
#
# timer: 1.3988 sec.
# iter 240 || Loss: 8.0276 || 01:22:55 AM
#
#
# timer: 1.3884 sec.
# iter 250 || Loss: 7.6431 || 01:23:16 AM
#
#
# timer: 1.3832 sec.
# iter 260 || Loss: 7.3525 || 01:23:44 AM
#
#
# timer: 1.1935 sec.
# iter 270 || Loss: 8.0487 || 01:24:07 AM
#
#
# timer: 1.2885 sec.
# iter 280 || Loss: 7.7970 || 01:24:36 AM
#
#
# timer: 1.4952 sec.
# iter 290 || Loss: 7.9166 || 01:24:57 AM
#
#
# timer: 1.0990 sec.
# iter 300 || Loss: 7.1307 || 01:25:24 AM
#
#
# Saving state, iter: 300
# timer: 1.1927 sec.
# iter 310 || Loss: 7.3924 || 01:25:48 AM
#
#
# timer: 1.3790 sec.
# iter 320 || Loss: 7.1847 || 01:26:15 AM
#
#
# timer: 0.9951 sec.
# iter 330 || Loss: 7.6237 || 01:26:42 AM
#
#
# timer: 0.9722 sec.
# iter 340 || Loss: 7.5265 || 01:27:11 AM
#
#
# timer: 0.8962 sec.
# iter 350 || Loss: 7.6244 || 01:27:32 AM
#
#
# timer: 0.9965 sec.
# iter 360 || Loss: 7.1731 || 01:27:54 AM
#
#
# timer: 1.0980 sec.
# iter 370 || Loss: 7.5977 || 01:28:22 AM
#
#
# timer: 1.0961 sec.
# iter 380 || Loss: 7.6519 || 01:28:46 AM
#
#
# timer: 1.1893 sec.
# iter 390 || Loss: 7.7160 || 01:29:12 AM
#
#
# timer: 0.9946 sec.
# iter 400 || Loss: 7.5513 || 01:29:36 AM
#
#
# Saving state, iter: 400
# timer: 1.0837 sec.
# iter 410 || Loss: 7.4029 || 01:30:04 AM
#
#
# timer: 1.0952 sec.
# iter 420 || Loss: 7.1984 || 01:30:26 AM
#
#
# timer: 0.9988 sec.
# iter 430 || Loss: 7.0829 || 01:30:52 AM
#
#
# timer: 1.3969 sec.
# iter 440 || Loss: 7.1932 || 01:31:15 AM
#
#
# timer: 1.0798 sec.
# iter 450 || Loss: 7.7474 || 01:31:43 AM
#
#
# timer: 1.0954 sec.
# iter 460 || Loss: 7.1726 || 01:32:06 AM
#
#
# timer: 1.1775 sec.
# iter 470 || Loss: 7.3481 || 01:32:34 AM
#
#
# timer: 1.3015 sec.
# iter 480 || Loss: 7.5168 || 01:32:55 AM
#
#
# timer: 1.1873 sec.
# iter 490 || Loss: 7.1774 || 01:33:23 AM
#
#
# timer: 1.2953 sec.
# iter 500 || Loss: 6.9039 || 01:33:45 AM
#
#
# Saving state, iter: 500
# timer: 1.1987 sec.
# iter 510 || Loss: 7.2687 || 01:34:15 AM
#
#
# timer: 1.4953 sec.
# iter 520 || Loss: 7.1698 || 01:34:37 AM
#
#
# timer: 0.8944 sec.
# iter 530 || Loss: 6.7085 || 01:35:03 AM
#
#
# timer: 1.0956 sec.
# iter 540 || Loss: 7.1114 || 01:35:26 AM
#
#
# timer: 1.1953 sec.
# iter 550 || Loss: 7.1567 || 01:35:54 AM
#
#
# timer: 1.0921 sec.
# iter 560 || Loss: 6.8494 || 01:36:17 AM
#
#
# timer: 1.2958 sec.
# iter 570 || Loss: 6.8276 || 01:36:48 AM
#
#
# timer: 1.1954 sec.
# iter 580 || Loss: 7.4236 || 01:37:10 AM
#
#
# timer: 1.0950 sec.
# iter 590 || Loss: 7.1922 || 01:37:38 AM
#
#
# timer: 1.4012 sec.
# iter 600 || Loss: 6.8740 || 01:38:00 AM
#
#
# Saving state, iter: 600
# timer: 1.2932 sec.
# iter 610 || Loss: 6.8573 || 01:38:27 AM
#
#
# timer: 1.0955 sec.
# iter 620 || Loss: 6.7640 || 01:38:48 AM
#
#
# timer: 1.0953 sec.
# iter 630 || Loss: 7.2360 || 01:39:16 AM
#
#
# timer: 1.0958 sec.
# iter 640 || Loss: 6.9841 || 01:39:38 AM
#
#
# timer: 1.1955 sec.
# iter 650 || Loss: 6.7676 || 01:40:06 AM
#
#
# timer: 1.1953 sec.
# iter 660 || Loss: 6.9302 || 01:40:28 AM
#
#
# timer: 1.1943 sec.
# iter 670 || Loss: 7.2441 || 01:40:55 AM
#
#
# timer: 1.1942 sec.
# iter 680 || Loss: 7.3239 || 01:41:19 AM
#
#
# timer: 1.0018 sec.
# iter 690 || Loss: 7.1601 || 01:41:44 AM
#
#
# timer: 1.0960 sec.
# iter 700 || Loss: 6.8815 || 01:42:07 AM
#
#
# Saving state, iter: 700
# timer: 1.0989 sec.
# iter 710 || Loss: 6.7899 || 01:42:36 AM
#
#
# timer: 1.1887 sec.
# iter 720 || Loss: 7.0453 || 01:43:01 AM
#
#
# timer: 1.5014 sec.
# iter 730 || Loss: 7.2707 || 01:43:26 AM
#
#
# timer: 1.1954 sec.
# iter 740 || Loss: 6.6232 || 01:43:50 AM
#
#
# timer: 1.2958 sec.
# iter 750 || Loss: 6.9022 || 01:44:19 AM
#
#
# timer: 1.1958 sec.
# iter 760 || Loss: 6.7033 || 01:44:41 AM
#
#
# timer: 1.2069 sec.
# iter 770 || Loss: 6.9614 || 01:45:08 AM
#
#
# timer: 1.2961 sec.
# iter 780 || Loss: 7.0030 || 01:45:32 AM
#
#
# timer: 1.0952 sec.
# iter 790 || Loss: 6.9901 || 01:46:01 AM
#
#
# timer: 1.4944 sec.
# iter 800 || Loss: 7.0626 || 01:46:24 AM
#
#
# Saving state, iter: 800
# timer: 1.0057 sec.
# iter 810 || Loss: 7.0633 || 01:46:48 AM
#
#
# timer: 0.9853 sec.
# iter 820 || Loss: 7.0228 || 01:47:11 AM
#
#
# timer: 1.1905 sec.
# iter 830 || Loss: 6.4600 || 01:47:38 AM
#
#
# timer: 0.8971 sec.
# iter 840 || Loss: 6.6742 || 01:48:03 AM
#
#
# timer: 1.1950 sec.
# iter 850 || Loss: 7.0553 || 01:48:29 AM
#
#
# timer: 1.0891 sec.
# iter 860 || Loss: 6.7433 || 01:48:52 AM
#
#
# timer: 0.9959 sec.
# iter 870 || Loss: 6.8550 || 01:49:21 AM
#
#
# timer: 1.4991 sec.
# iter 880 || Loss: 6.9431 || 01:49:42 AM
#
#
# timer: 0.6649 sec.
# iter 890 || Loss: 6.7487 || 01:50:06 AM
#
#
# timer: 1.6913 sec.
# iter 900 || Loss: 6.5712 || 01:50:31 AM
#
#
# Saving state, iter: 900
# timer: 1.1953 sec.
# iter 910 || Loss: 6.8913 || 01:50:54 AM
#
#
# timer: 1.4955 sec.
# iter 920 || Loss: 6.4873 || 01:51:24 AM
#
#
# timer: 1.4957 sec.
# iter 930 || Loss: 6.8826 || 01:51:48 AM
#
#
# timer: 1.3852 sec.
# iter 940 || Loss: 6.8856 || 01:52:14 AM
#
#
# timer: 1.1953 sec.
# iter 950 || Loss: 6.6780 || 01:52:37 AM
#
#
# timer: 1.3896 sec.
# iter 960 || Loss: 7.0045 || 01:53:03 AM
#
#
# timer: 1.3921 sec.
# iter 970 || Loss: 6.5769 || 01:53:28 AM
#
#
# timer: 0.9959 sec.
# iter 980 || Loss: 6.2784 || 01:53:56 AM
#
#
# timer: 1.3925 sec.
# iter 990 || Loss: 6.7717 || 01:54:20 AM
#
#
# timer: 1.1958 sec.
# iter 1000 || Loss: 6.6887 || 01:54:46 AM
#
#
# Saving state, iter: 1000
# timer: 1.2946 sec.
# iter 1010 || Loss: 6.7676 || 01:55:10 AM
#
#
# timer: 1.1959 sec.
# iter 1020 || Loss: 6.8316 || 01:55:35 AM
#
#
# timer: 1.2954 sec.
# iter 1030 || Loss: 6.9607 || 01:56:01 AM
#
#
# timer: 0.9971 sec.
# iter 1040 || Loss: 6.8166 || 01:56:31 AM
#
#
# timer: 1.1940 sec.
# iter 1050 || Loss: 6.7021 || 01:56:53 AM
#
#
# timer: 0.8961 sec.
# iter 1060 || Loss: 6.4734 || 01:57:23 AM
#
#
# timer: 0.5587 sec.
# iter 1070 || Loss: 6.6225 || 01:57:41 AM
#
#
# timer: 0.9007 sec.
# iter 1080 || Loss: 6.5903 || 01:58:08 AM
#
#
# timer: 1.1971 sec.
# iter 1090 || Loss: 6.3780 || 01:58:33 AM
#
#
# timer: 1.5089 sec.
# iter 1100 || Loss: 6.9076 || 01:58:57 AM
#
#
# Saving state, iter: 1100
# timer: 1.1858 sec.
# iter 1110 || Loss: 6.4589 || 01:59:22 AM
#
#
# timer: 1.4958 sec.
# iter 1120 || Loss: 7.0187 || 01:59:48 AM
#
#
# timer: 1.3812 sec.
# iter 1130 || Loss: 6.6643 || 02:00:11 AM
#
#
# timer: 1.3957 sec.
# iter 1140 || Loss: 7.0907 || 02:00:41 AM
#
#
# timer: 1.0915 sec.
# iter 1150 || Loss: 6.4654 || 02:01:04 AM
#
#
# timer: 1.0944 sec.
# iter 1160 || Loss: 6.1455 || 02:01:34 AM
#
#
# timer: 1.7951 sec.
# iter 1170 || Loss: 6.3506 || 02:01:58 AM
#
#
# timer: 1.2954 sec.
# iter 1180 || Loss: 6.6483 || 02:02:25 AM
#
#
# timer: 1.3961 sec.
# iter 1190 || Loss: 6.6215 || 02:02:47 AM
#
#
# timer: 1.3961 sec.
# iter 1200 || Loss: 6.6661 || 02:03:15 AM
#
#
# Saving state, iter: 1200
# timer: 1.2954 sec.
# iter 1210 || Loss: 6.3507 || 02:03:36 AM
#
#
# timer: 1.3958 sec.
# iter 1220 || Loss: 6.4448 || 02:04:06 AM
#
#
# timer: 0.9956 sec.
# iter 1230 || Loss: 6.7499 || 02:04:27 AM
#
#
# timer: 1.0951 sec.
# iter 1240 || Loss: 6.4229 || 02:04:54 AM
#
#
# timer: 0.5646 sec.
# iter 1250 || Loss: 6.4645 || 02:05:13 AM
#
#
# timer: 1.1954 sec.
# iter 1260 || Loss: 6.4976 || 02:05:43 AM
#
#
# timer: 1.1984 sec.
# iter 1270 || Loss: 6.8431 || 02:06:10 AM
#
#
# timer: 0.9892 sec.
# iter 1280 || Loss: 6.2425 || 02:06:32 AM
# timer: 1.0951 sec.
# iter 1290 || Loss: 6.7013 || 02:06:59 AM
#
#
# timer: 1.2958 sec.
# iter 1300 || Loss: 6.4698 || 02:07:23 AM
#
#
# Saving state, iter: 1300
# timer: 1.1958 sec.
# iter 1310 || Loss: 6.3012 || 02:07:50 AM
#
#
# timer: 1.7940 sec.
# iter 1320 || Loss: 6.5029 || 02:08:14 AM
#
#
# timer: 1.2014 sec.
# iter 1330 || Loss: 6.0869 || 02:08:42 AM
#
#
# timer: 1.1987 sec.
# iter 1340 || Loss: 6.5163 || 02:09:05 AM
#
#
# timer: 1.3939 sec.
# iter 1350 || Loss: 6.3836 || 02:09:33 AM
#
#
# timer: 1.3940 sec.
# iter 1360 || Loss: 6.7624 || 02:09:56 AM
#
#
# timer: 1.1954 sec.
# iter 1370 || Loss: 6.7928 || 02:10:23 AM
#
#
# timer: 1.1953 sec.
# iter 1380 || Loss: 6.6238 || 02:10:45 AM
#
#
# timer: 1.2947 sec.
# iter 1390 || Loss: 6.6228 || 02:11:11 AM
#
#
# timer: 0.9953 sec.
# iter 1400 || Loss: 6.4597 || 02:11:36 AM
#
#
# Saving state, iter: 1400
# timer: 1.0886 sec.
# iter 1410 || Loss: 6.5506 || 02:12:03 AM
#
#
# timer: 1.1954 sec.
# iter 1420 || Loss: 6.1787 || 02:12:24 AM
#
#
# timer: 0.5492 sec.
# iter 1430 || Loss: 6.8672 || 02:12:45 AM
#
#
# timer: 1.0989 sec.
# iter 1440 || Loss: 6.2248 || 02:13:14 AM
#
#
# timer: 1.5905 sec.
# iter 1450 || Loss: 6.6745 || 02:13:42 AM
#
#
# timer: 1.1961 sec.
# iter 1460 || Loss: 6.4687 || 02:14:08 AM
#
#
# timer: 1.0941 sec.
# iter 1470 || Loss: 6.3439 || 02:14:32 AM
#
#
# timer: 1.1942 sec.
# iter 1480 || Loss: 6.1058 || 02:15:02 AM
#
#
# timer: 1.0936 sec.
# iter 1490 || Loss: 6.5655 || 02:15:24 AM
#
#
# timer: 1.4871 sec.
# iter 1500 || Loss: 6.3007 || 02:15:52 AM
#
#
# Saving state, iter: 1500
# timer: 1.3935 sec.
# iter 1510 || Loss: 6.6665 || 02:16:14 AM
#
#
# timer: 1.3872 sec.
# iter 1520 || Loss: 6.3373 || 02:16:43 AM
#
#
# timer: 1.1962 sec.
# iter 1530 || Loss: 6.2604 || 02:17:07 AM
#
#
# timer: 0.8763 sec.
# iter 1540 || Loss: 6.6397 || 02:17:34 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5a35a542b90d> in <module>
#       1 momentum = 0.1
# ----> 2 train(device, resume, momentum)
#       3
#       4 with open('trained_weights/vgg16_ssd_stats_momentum'+str(momentum)+'.pkl','rb') as f:
#       5     l_loss, c_loss, itr = pickle.load(f)
#
# <ipython-input-9-38c9a1adf9a6> in train(device, resume, momentum)
#     106         optimizer.zero_grad()
#     107
# --> 108         loss_l, loss_c = criterion(out, targets)
#     109         loss = loss_l + loss_c
#     110
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/mlip_proj/final/ssd-master_qfgaohao/layers/modules/multibox_loss.py in forward(self, predictions, targets)
#      71             defaults = priors.data
#      72             match(self.threshold, truths, defaults, self.variance, labels,
# ---> 73                   loc_t, conf_t, idx)
#      74         if self.use_gpu:
#      75             loc_t = loc_t.cuda()
#
# ~/mlip_proj/final/ssd-master_qfgaohao/layers/box_utils.py in match(threshold, truths, priors, variances, labels, loc_t, conf_t, idx)
#      88     overlaps = jaccard(
#      89         truths,
# ---> 90         point_form(priors)
#      91     )
#      92     # (Bipartite Matching)
#
# ~/mlip_proj/final/ssd-master_qfgaohao/layers/box_utils.py in jaccard(box_a, box_b)
#      62     area_a = ((box_a[:, 2]-box_a[:, 0]) *
#      63               (box_a[:, 3]-box_a[:, 1])).unsqueeze(1).expand_as(inter)  # [A,B]
# ---> 64     area_b = ((box_b[:, 2]-box_b[:, 0]) *
#      65               (box_b[:, 3]-box_b[:, 1])).unsqueeze(0).expand_as(inter)  # [A,B]
#      66     union = area_a + area_b - inter
#
# KeyboardInterrupt:

# %%
with open('trained_weights/vgg16_ssd_stats_momentum'+str(momentum)+'.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)
plt.plot(itr,l_loss+c_loss)
plt.title('Loss - Iterations: lr=1e-3  SGD with momentum'+str(momentum)+ ' Optimizer')
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
momentum = 1.
train(device, resume, momentum)
# Out:
# change log in ssd.py
# Loading base network...
# Initializing weights...
# Loading the dataset...
# Training SSD on:  train
# Images in the training set = 5717
# Images in a mini-batch = 32
# mini-batches = 179
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# STARTING - ITERATIONS

# %%
with open('trained_weights/vgg16_ssd_stats_momentum'+str(momentum)+'.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)
plt.plot(itr,l_loss+c_loss)
plt.title('Loss - Iterations: lr=1e-3  SGD with momentum'+str(momentum)+ ' Optimizer')
plt.xlabel('Iterations')
plt.ylabel('Loss')
