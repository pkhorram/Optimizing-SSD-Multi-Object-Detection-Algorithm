# %%
# %load_ext autoreload

# %autoreload 2



import torch
from vision.ssd.vgg_ssd import create_vgg_ssd, create_vgg_ssd_predictor
from vision.datasets.voc_dataset import VOCDataset

from vision.utils import box_utils, measurements
from vision.utils.misc import str2bool, Timer
import argparse
import pathlib
import numpy as np
import logging
import sys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda

# %%
def group_annotation_by_class(dataset):
    true_case_stat = {}
    all_gt_boxes = {}
    all_difficult_cases = {}
    for i in range(len(dataset)):
        image_id, annotation = dataset.get_annotation(i)
        gt_boxes, classes, is_difficult = annotation
        gt_boxes = torch.from_numpy(gt_boxes)
        for i, difficult in enumerate(is_difficult):
            class_index = int(classes[i])
            gt_box = gt_boxes[i]
            if not difficult:
                true_case_stat[class_index] = true_case_stat.get(class_index, 0) + 1

            if class_index not in all_gt_boxes:
                all_gt_boxes[class_index] = {}
            if image_id not in all_gt_boxes[class_index]:
                all_gt_boxes[class_index][image_id] = []
            all_gt_boxes[class_index][image_id].append(gt_box)
            if class_index not in all_difficult_cases:
                all_difficult_cases[class_index]={}
            if image_id not in all_difficult_cases[class_index]:
                all_difficult_cases[class_index][image_id] = []
            all_difficult_cases[class_index][image_id].append(difficult)

    for class_index in all_gt_boxes:
        for image_id in all_gt_boxes[class_index]:
            all_gt_boxes[class_index][image_id] = torch.stack(all_gt_boxes[class_index][image_id])
    for class_index in all_difficult_cases:
        for image_id in all_difficult_cases[class_index]:
            all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
    return true_case_stat, all_gt_boxes, all_difficult_cases

# %%
def compute_average_precision_per_class(num_true_cases, gt_boxes, difficult_cases,
                                        prediction_file, iou_threshold, use_2007_metric):
    with open(prediction_file) as f:
        image_ids = []
        boxes = []
        scores = []
        for line in f:
            t = line.rstrip().split(" ")
            image_ids.append(t[0])
            scores.append(float(t[1]))
            box = torch.tensor([float(v) for v in t[2:]]).unsqueeze(0)
            box -= 1.0  # convert to python format where indexes start from 0
            boxes.append(box)
        scores = np.array(scores)
        sorted_indexes = np.argsort(-scores)
        boxes = [boxes[i] for i in sorted_indexes]
        image_ids = [image_ids[i] for i in sorted_indexes]
        true_positive = np.zeros(len(image_ids))
        false_positive = np.zeros(len(image_ids))
        matched = set()
        for i, image_id in enumerate(image_ids):
            box = boxes[i]
            if image_id not in gt_boxes:
                false_positive[i] = 1
                continue

            gt_box = gt_boxes[image_id]
            ious = box_utils.iou_of(box, gt_box)
            max_iou = torch.max(ious).item()
            max_arg = torch.argmax(ious).item()
            if max_iou > iou_threshold:
                if difficult_cases[image_id][max_arg] == 0:
                    if (image_id, max_arg) not in matched:
                        true_positive[i] = 1
                        matched.add((image_id, max_arg))
                    else:
                        false_positive[i] = 1
            else:
                false_positive[i] = 1

    true_positive = true_positive.cumsum()
    false_positive = false_positive.cumsum()
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / num_true_cases
    if use_2007_metric:
        return measurements.compute_voc2007_average_precision(precision, recall)
    else:
        return measurements.compute_average_precision(precision, recall)

# %%
dataset_type = "voc"
use_cuda=True
use_2007_metric=True
nms_method="hard"
iou_threshold=0.5
mb2_width_mult=1.0
eval_dir = "results_vgg16_eval_trainset"
#dataset = "~/data/VOC0712/VOC2012/"
dataset = "/datasets/ee285f-public/PascalVOC2012/"
label_file = "models/voc-model-labels.txt"
trained_model = "models/vgg16-ssd-mp-0_7726.pth"
eval_mode = "val"

# %%
eval_path = pathlib.Path(eval_dir) #
eval_path.mkdir(exist_ok=True)
timer = Timer()
class_names = [name.strip() for name in open(label_file).readlines()]

dataset = VOCDataset(dataset, is_test=eval_mode ) #is_test just signifies dataset type here : False: train dataset ; True: test dataset

true_case_stat, all_gb_boxes, all_difficult_cases = group_annotation_by_class(dataset)

net = create_vgg_ssd(len(class_names), is_test=True)


timer.start("Load Model")
net.load(trained_model)
net = net.to(DEVICE)
print(f'It took {timer.end("Load Model")} seconds to load the model.')

predictor = create_vgg_ssd_predictor(net, nms_method=nms_method, device=DEVICE)

results = []
for i in range(len(dataset)):
    print("process image", i)
    timer.start("Load Image")
    image = dataset.get_image(i)
    print("Load Image: {:4f} seconds.".format(timer.end("Load Image")))
    timer.start("Predict")
    boxes, labels, probs = predictor.predict(image)
    print("Prediction: {:4f} seconds.".format(timer.end("Predict")))
    indexes = torch.ones(labels.size(0), 1, dtype=torch.float32) * i
    results.append(torch.cat([
        indexes.reshape(-1, 1),
        labels.reshape(-1, 1).float(),
        probs.reshape(-1, 1),
        boxes + 1.0  # matlab's indexes start from 1
    ], dim=1))
results = torch.cat(results)
for class_index, class_name in enumerate(class_names):
    if class_index == 0: continue  # ignore background
    prediction_path = eval_path / f"det_test_{class_name}.txt"
    with open(prediction_path, "w") as f:
        sub = results[results[:, 1] == class_index, :]
        for i in range(sub.size(0)):
            prob_box = sub[i, 2:].numpy()
            image_id = dataset.ids[int(sub[i, 0])]
            print(
                image_id + " " + " ".join([str(v) for v in prob_box]),
                file=f
            )
aps = []
print("\n\nAverage Precision Per-class:")
for class_index, class_name in enumerate(class_names):
    if class_index == 0:
        continue
    prediction_path = eval_path / f"det_test_{class_name}.txt"
    ap = compute_average_precision_per_class(
        true_case_stat[class_index],
        all_gb_boxes[class_index],
        all_difficult_cases[class_index],
        prediction_path,
        iou_threshold,
        use_2007_metric
    )
    aps.append(ap)
    print(f"{class_name}: {ap}")

print(f"\nAverage Precision Across All Classes:{sum(aps)/len(aps)}")
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# It took 0.9950439929962158 seconds to load the model.
# process image 0
# Load Image: 0.011107 seconds.
# Inference time:  0.04694366455078125
# Prediction: 0.070259 seconds.
# process image 1
# Load Image: 0.007300 seconds.
# Inference time:  0.00501251220703125
# Prediction: 0.095648 seconds.
# process image 2
# Load Image: 0.013796 seconds.
# Inference time:  0.012418270111083984
# Prediction: 0.194059 seconds.
# process image 3
# Load Image: 0.007278 seconds.
# Inference time:  0.006540060043334961
# Prediction: 0.083690 seconds.
# process image 4
# Load Image: 0.005837 seconds.
# Inference time:  0.06608271598815918
# Prediction: 0.085538 seconds.
# process image 5
# Load Image: 0.006668 seconds.
# Inference time:  0.006455421447753906
# Prediction: 0.191888 seconds.
# process image 6
# Load Image: 0.008759 seconds.
# Inference time:  0.008230447769165039
# Prediction: 0.105345 seconds.
# process image 7
# Load Image: 0.071999 seconds.
# Inference time:  0.0878438949584961
# Prediction: 0.124996 seconds.
# process image 8
# Load Image: 0.008026 seconds.
# Inference time:  0.00611114501953125
# Prediction: 0.186589 seconds.
# process image 9
# Load Image: 0.005947 seconds.
# Inference time:  0.06527590751647949
# Prediction: 0.100028 seconds.
# process image 10
# Load Image: 0.014048 seconds.
# Inference time:  0.0070400238037109375
# Prediction: 0.074156 seconds.
# process image 11
# Load Image: 0.008028 seconds.
# Inference time:  0.015210390090942383
# Prediction: 0.102363 seconds.
# process image 12
# Load Image: 0.005228 seconds.
# Inference time:  0.011046648025512695
# Prediction: 0.198078 seconds.
# process image 13
# Load Image: 0.006409 seconds.
# Inference time:  0.005764961242675781
# Prediction: 0.105648 seconds.
# process image 14
# Load Image: 0.001609 seconds.
# Inference time:  0.04945230484008789
# Prediction: 0.072260 seconds.
# process image 15
# Load Image: 0.004645 seconds.
# Inference time:  0.010142803192138672
# Prediction: 0.206946 seconds.
# process image 16
# Load Image: 0.006136 seconds.
# Inference time:  0.004518747329711914
# Prediction: 0.075119 seconds.
# process image 17
# Load Image: 0.010557 seconds.
# Inference time:  0.007163286209106445
# Prediction: 0.193231 seconds.
# process image 18
# Load Image: 0.012177 seconds.
# Inference time:  0.07510042190551758
# Prediction: 0.086915 seconds.
# process image 19
# Load Image: 0.005342 seconds.
# Inference time:  0.008903741836547852
# Prediction: 0.193383 seconds.
# process image 20
# Load Image: 0.009501 seconds.
# Inference time:  0.004370450973510742
# Prediction: 0.082621 seconds.
# process image 21
# Load Image: 0.006586 seconds.
# Inference time:  0.007887125015258789
# Prediction: 0.082414 seconds.
# process image 22
# Load Image: 0.017096 seconds.
# Inference time:  0.008327722549438477
# Prediction: 0.101218 seconds.
# process image 23
# Load Image: 0.009657 seconds.
# Inference time:  0.09451580047607422
# Prediction: 0.190021 seconds.
# process image 24
# Load Image: 0.009797 seconds.
# Inference time:  0.0838477611541748
# Prediction: 0.170308 seconds.
# process image 25
# Load Image: 0.013433 seconds.
# Inference time:  0.015288114547729492
# Prediction: 0.095566 seconds.
# process image 26
# Load Image: 0.078324 seconds.
# Inference time:  0.09561467170715332
# Prediction: 0.140101 seconds.
# process image 27
# Load Image: 0.007084 seconds.
# Inference time:  0.006890773773193359
# Prediction: 0.075566 seconds.
# process image 28
# Load Image: 0.078919 seconds.
# Inference time:  0.08268046379089355
# Prediction: 0.128492 seconds.
# process image 29
# Load Image: 0.006669 seconds.
# Inference time:  0.012651681900024414
# Prediction: 0.098804 seconds.
# process image 30
# Load Image: 0.063359 seconds.
# Inference time:  0.09184956550598145
# Prediction: 0.120105 seconds.
# process image 31
# Load Image: 0.008666 seconds.
# Inference time:  0.009298563003540039
# Prediction: 0.086614 seconds.
# process image 32
# Load Image: 0.015035 seconds.
# Inference time:  0.09052515029907227
# Prediction: 0.191129 seconds.
# process image 33
# Load Image: 0.005785 seconds.
# Inference time:  0.0745241641998291
# Prediction: 0.105583 seconds.
# process image 34
# Load Image: 0.003788 seconds.
# Inference time:  0.09500932693481445
# Prediction: 0.173322 seconds.
# process image 35
# Load Image: 0.011741 seconds.
# Inference time:  0.006934165954589844
# Prediction: 0.101114 seconds.
# process image 36
# Load Image: 0.009313 seconds.
# Inference time:  0.07178092002868652
# Prediction: 0.082679 seconds.
# process image 37
# Load Image: 0.009020 seconds.
# Inference time:  0.08054137229919434
# Prediction: 0.198093 seconds.
# process image 38
# Load Image: 0.003295 seconds.
# Inference time:  0.06744027137756348
# Prediction: 0.115756 seconds.
# process image 39
# Load Image: 0.004535 seconds.
# Inference time:  0.004710197448730469
# Prediction: 0.183292 seconds.
# process image 40
# Load Image: 0.005752 seconds.
# Inference time:  0.05237627029418945
# Prediction: 0.077426 seconds.
# process image 41
# Load Image: 0.005647 seconds.
# Inference time:  0.08117032051086426
# Prediction: 0.183533 seconds.
# process image 42
# Load Image: 0.010680 seconds.
# Inference time:  0.015260696411132812
# Prediction: 0.108910 seconds.
# process image 43
# Load Image: 0.006729 seconds.
# Inference time:  0.010238885879516602
# Prediction: 0.185273 seconds.
# process image 44
# Load Image: 0.004917 seconds.
# Inference time:  0.006284952163696289
# Prediction: 0.085931 seconds.
# process image 45
# Load Image: 0.084942 seconds.
# Inference time:  0.08689618110656738
# Prediction: 0.110165 seconds.
# process image 46
# Load Image: 0.009523 seconds.
# Inference time:  0.08443069458007812
# Prediction: 0.120990 seconds.
# process image 47
# Load Image: 0.005197 seconds.
# Inference time:  0.007719755172729492
# Prediction: 0.090652 seconds.
# process image 48
# Load Image: 0.004032 seconds.
# Inference time:  0.014636754989624023
# Prediction: 0.191013 seconds.
# process image 49
# Load Image: 0.005742 seconds.
# Inference time:  0.09568428993225098
# Prediction: 0.194280 seconds.
# process image 50
# Load Image: 0.006028 seconds.
# Inference time:  0.014734506607055664
# Prediction: 0.181326 seconds.
# process image 51
# Load Image: 0.006612 seconds.
# Inference time:  0.07384371757507324
# Prediction: 0.095582 seconds.
# process image 52
# Load Image: 0.006868 seconds.
# Inference time:  0.004515171051025391
# Prediction: 0.194858 seconds.
# process image 53
# Load Image: 0.005808 seconds.
# Inference time:  0.06496930122375488
# Prediction: 0.085758 seconds.
# process image 54
# Load Image: 0.005993 seconds.
# Inference time:  0.06717181205749512
# Prediction: 0.088555 seconds.
# process image 55
# Load Image: 0.008271 seconds.
# Inference time:  0.015438318252563477
# Prediction: 0.180908 seconds.
# process image 56
# Load Image: 0.009391 seconds.
# Inference time:  0.07850074768066406
# Prediction: 0.101300 seconds.
# process image 57
# Load Image: 0.009793 seconds.
# Inference time:  0.07521557807922363
# Prediction: 0.116178 seconds.
# process image 58
# Load Image: 0.052635 seconds.
# Inference time:  0.012036561965942383
# Prediction: 0.121711 seconds.
# process image 59
# Load Image: 0.010982 seconds.
# Inference time:  0.015334606170654297
# Prediction: 0.100208 seconds.
# process image 60
# Prediction: 0.190656 seconds.
# process image 88
# Load Image: 0.007791 seconds.
# Inference time:  0.009523630142211914
# Prediction: 0.088838 seconds.
# process image 89
# Load Image: 0.080869 seconds.
# Inference time:  0.09507298469543457
# Prediction: 0.133242 seconds.
# process image 90
# Load Image: 0.005156 seconds.
# Inference time:  0.056725263595581055
# Prediction: 0.080416 seconds.
# process image 91
# Load Image: 0.003515 seconds.
# Inference time:  0.09550929069519043
# Prediction: 0.202193 seconds.
# process image 92
# Load Image: 0.006919 seconds.
# Inference time:  0.0695488452911377
# Prediction: 0.087441 seconds.
# process image 93
# Load Image: 0.004914 seconds.
# Inference time:  0.012861967086791992
# Prediction: 0.212133 seconds.
# process image 94
# Load Image: 0.011730 seconds.
# Inference time:  0.008215904235839844
# Prediction: 0.068722 seconds.
# process image 95
# Load Image: 0.005110 seconds.
# Inference time:  0.007535696029663086
# Prediction: 0.191783 seconds.
# process image 96
# Load Image: 0.006853 seconds.
# Inference time:  0.06996417045593262
# Prediction: 0.092377 seconds.
# process image 97
# Load Image: 0.004530 seconds.
# Inference time:  0.01577472686767578
# Prediction: 0.208830 seconds.
# process image 98
# Load Image: 0.004861 seconds.
# Inference time:  0.004772186279296875
# Prediction: 0.067473 seconds.
# process image 99
# Load Image: 0.095464 seconds.
# Inference time:  0.009320735931396484
# Prediction: 0.127828 seconds.
# process image 100
# Load Image: 0.007090 seconds.
# Inference time:  0.05564379692077637
# Prediction: 0.075363 seconds.
# process image 101
# Load Image: 0.016861 seconds.
# Inference time:  0.010708093643188477
# Prediction: 0.199896 seconds.
# process image 102
# Load Image: 0.006394 seconds.
# Inference time:  0.004803180694580078
# Prediction: 0.108979 seconds.
# process image 103
# Load Image: 0.004388 seconds.
# Inference time:  0.09448909759521484
# Prediction: 0.158484 seconds.
# process image 104
# Load Image: 0.011325 seconds.
# Inference time:  0.0804128646850586
# Prediction: 0.131998 seconds.
# process image 105
# Load Image: 0.004153 seconds.
# Inference time:  0.008401870727539062
# Prediction: 0.182233 seconds.
# process image 106
# Load Image: 0.008460 seconds.
# Inference time:  0.057409048080444336
# Prediction: 0.074810 seconds.
# process image 107
# Load Image: 0.007232 seconds.
# Inference time:  0.09404635429382324
# Prediction: 0.194471 seconds.
# process image 108
# Load Image: 0.008527 seconds.
# Inference time:  0.004491567611694336
# Prediction: 0.081428 seconds.
# process image 109
# Load Image: 0.003451 seconds.
# Inference time:  0.005885124206542969
# Prediction: 0.183633 seconds.
# process image 110
# Load Image: 0.009909 seconds.
# Inference time:  0.011387109756469727
# Prediction: 0.104782 seconds.
# process image 111
# Load Image: 0.006116 seconds.
# Inference time:  0.004452705383300781
# Prediction: 0.115384 seconds.
# process image 112
# Load Image: 0.056824 seconds.
# Inference time:  0.008306741714477539
# Prediction: 0.020189 seconds.
# process image 113
# Load Image: 0.091519 seconds.
# Inference time:  0.08206820487976074
# Prediction: 0.126555 seconds.
# process image 114
# Load Image: 0.005064 seconds.
# Inference time:  0.006272792816162109
# Prediction: 0.184821 seconds.
# process image 115
# Inference time:  0.046778202056884766
# Prediction: 0.067757 seconds.
# process image 143
# Load Image: 0.007109 seconds.
# Inference time:  0.006899118423461914
# Prediction: 0.205204 seconds.
# process image 144
# Load Image: 0.007062 seconds.
# Inference time:  0.011558771133422852
# Prediction: 0.101835 seconds.
# process image 145
# Load Image: 0.005156 seconds.
# Inference time:  0.0065004825592041016
# Prediction: 0.074993 seconds.
# process image 146
# Load Image: 0.085615 seconds.
# Inference time:  0.0865623950958252
# Prediction: 0.103041 seconds.
# process image 147
# Load Image: 0.015597 seconds.
# Inference time:  0.013815879821777344
# Prediction: 0.205123 seconds.
# process image 148
# Load Image: 0.005242 seconds.
# Inference time:  0.05635476112365723
# Prediction: 0.085974 seconds.
# process image 149
# Load Image: 0.003606 seconds.
# Inference time:  0.009288311004638672
# Prediction: 0.090221 seconds.
# process image 150
# Load Image: 0.092543 seconds.
# Inference time:  0.008655548095703125
# Prediction: 0.118473 seconds.
# process image 151
# Load Image: 0.004742 seconds.
# Inference time:  0.014196395874023438
# Prediction: 0.188407 seconds.
# process image 152
# Load Image: 0.007456 seconds.
# Inference time:  0.0047588348388671875
# Prediction: 0.075692 seconds.
# process image 153
# Load Image: 0.009691 seconds.
# Inference time:  0.012787580490112305
# Prediction: 0.199891 seconds.
# process image 154
# Load Image: 0.008358 seconds.
# Inference time:  0.0687553882598877
# Prediction: 0.091015 seconds.
# process image 155
# Load Image: 0.008107 seconds.
# Inference time:  0.07530570030212402
# Prediction: 0.101160 seconds.
# process image 156
# Load Image: 0.005766 seconds.
# Inference time:  0.006457090377807617
# Prediction: 0.166089 seconds.
# process image 157
# Load Image: 0.007839 seconds.
# Inference time:  0.006318092346191406
# Prediction: 0.103237 seconds.
# process image 158
# Load Image: 0.005275 seconds.
# Inference time:  0.012352466583251953
# Prediction: 0.191316 seconds.
# process image 159
# Load Image: 0.004556 seconds.
# Inference time:  0.008011341094970703
# Prediction: 0.084536 seconds.
# process image 160
# Load Image: 0.020939 seconds.
# Inference time:  0.07102775573730469
# Prediction: 0.103836 seconds.
# process image 161
# Load Image: 0.002395 seconds.
# Inference time:  0.005810737609863281
# Prediction: 0.075060 seconds.
# process image 162
# Load Image: 0.005699 seconds.
# Inference time:  0.08869719505310059
# Prediction: 0.227980 seconds.
# process image 163
# Load Image: 0.018139 seconds.
# Inference time:  0.03992128372192383
# Prediction: 0.062516 seconds.
# process image 164
# Load Image: 0.007387 seconds.
# Inference time:  0.014799833297729492
# Prediction: 0.185841 seconds.
# process image 165
# Load Image: 0.003137 seconds.
# Inference time:  0.006032705307006836
# Prediction: 0.017398 seconds.
# process image 166
# Load Image: 0.070096 seconds.
# Inference time:  0.00764918327331543
# Prediction: 0.110508 seconds.
# process image 167
# Load Image: 0.059333 seconds.
# Inference time:  0.010765790939331055
# Prediction: 0.129954 seconds.
# process image 168
# Load Image: 0.011396 seconds.
# Inference time:  0.011335611343383789
# Prediction: 0.023531 seconds.
# process image 169
# Load Image: 0.057089 seconds.
# Inference time:  0.09009408950805664
# Prediction: 0.105973 seconds.
# Prediction: 0.117678 seconds.
# process image 225
# Load Image: 0.467778 seconds.
# Inference time:  0.0954582691192627
# Prediction: 0.152172 seconds.
# process image 226
# Load Image: 0.005702 seconds.
# Inference time:  0.007464170455932617
# Prediction: 0.165622 seconds.
# process image 227
# Load Image: 0.009196 seconds.
# Inference time:  0.004155158996582031
# Prediction: 0.098510 seconds.
# process image 228
# Load Image: 0.004204 seconds.
# Inference time:  0.004873752593994141
# Prediction: 0.162625 seconds.
# process image 229
# Load Image: 0.003877 seconds.
# Inference time:  0.08810734748840332
# Prediction: 0.103127 seconds.
# process image 230
# Load Image: 0.005048 seconds.
# Inference time:  0.011754512786865234
# Prediction: 0.127065 seconds.
# process image 231
# Load Image: 0.004453 seconds.
# Inference time:  0.0964207649230957
# Prediction: 0.162428 seconds.
# process image 232
# Load Image: 0.005678 seconds.
# Inference time:  0.07966923713684082
# Prediction: 0.104670 seconds.
# process image 233
# Load Image: 0.005208 seconds.
# Inference time:  0.09595632553100586
# Prediction: 0.213787 seconds.
# process image 234
# Load Image: 0.005752 seconds.
# Inference time:  0.055635929107666016
# Prediction: 0.074226 seconds.
# process image 235
# Load Image: 0.008563 seconds.
# Inference time:  0.011660099029541016
# Prediction: 0.200631 seconds.
# process image 236
# Load Image: 0.005659 seconds.
# Inference time:  0.09815835952758789
# Prediction: 0.187595 seconds.
# process image 237
# Load Image: 0.008608 seconds.
# Inference time:  0.09340620040893555
# Prediction: 0.188982 seconds.
# process image 238
# Load Image: 0.005184 seconds.
# Inference time:  0.007489681243896484
# Prediction: 0.094699 seconds.
# process image 239
# Load Image: 0.005316 seconds.
# Inference time:  0.00487065315246582
# Prediction: 0.183359 seconds.
# process image 240
# Load Image: 0.005934 seconds.
# Inference time:  0.011952877044677734
# Prediction: 0.225264 seconds.
# process image 241
# Load Image: 0.006407 seconds.
# Inference time:  0.04591679573059082
# Prediction: 0.088802 seconds.
# process image 242
# Load Image: 0.004526 seconds.
# Inference time:  0.0069408416748046875
# Prediction: 0.169316 seconds.
# process image 243
# Load Image: 0.007314 seconds.
# Inference time:  0.008192300796508789
# Prediction: 0.091561 seconds.
# process image 244
# Load Image: 0.009115 seconds.
# Inference time:  0.012614727020263672
# Prediction: 0.226262 seconds.
# process image 245
# Load Image: 0.003363 seconds.
# Inference time:  0.009936332702636719
# Prediction: 0.164062 seconds.
# process image 246
# Load Image: 0.006736 seconds.
# Inference time:  0.09428691864013672
# Prediction: 0.213230 seconds.
# process image 247
# Load Image: 0.007378 seconds.
# Inference time:  0.0055980682373046875
# Prediction: 0.087927 seconds.
# process image 248
# Load Image: 0.004187 seconds.
# Inference time:  0.005524158477783203
# Prediction: 0.182198 seconds.
# process image 249
# Load Image: 0.006380 seconds.
# Inference time:  0.09425830841064453
# Prediction: 0.215027 seconds.
# process image 250
# Load Image: 0.004794 seconds.
# Inference time:  0.006740093231201172
# Prediction: 0.071439 seconds.
# process image 251
# Load Image: 0.004660 seconds.
# Inference time:  0.0076143741607666016
# Prediction: 0.177254 seconds.
# process image 252
# Inference time:  0.012441396713256836
# Prediction: 0.183080 seconds.
# process image 280
# Load Image: 0.009028 seconds.
# Inference time:  0.08057093620300293
# Prediction: 0.126879 seconds.
# process image 281
# Load Image: 0.004185 seconds.
# Inference time:  0.053195953369140625
# Prediction: 0.065886 seconds.
# process image 282
# Load Image: 0.005240 seconds.
# Inference time:  0.009662389755249023
# Prediction: 0.218916 seconds.
# process image 283
# Load Image: 0.003901 seconds.
# Inference time:  0.006232500076293945
# Prediction: 0.074224 seconds.
# process image 284
# Load Image: 0.004503 seconds.
# Inference time:  0.010582685470581055
# Prediction: 0.208603 seconds.
# process image 285
# Load Image: 0.007151 seconds.
# Inference time:  0.061347246170043945
# Prediction: 0.085174 seconds.
# process image 286
# Load Image: 0.008303 seconds.
# Inference time:  0.009080171585083008
# Prediction: 0.199405 seconds.
# process image 287
# Load Image: 0.004657 seconds.
# Inference time:  0.004716157913208008
# Prediction: 0.080539 seconds.
# process image 288
# Load Image: 0.004095 seconds.
# Inference time:  0.004677534103393555
# Prediction: 0.201623 seconds.
# process image 289
# Load Image: 0.004945 seconds.
# Inference time:  0.013089179992675781
# Prediction: 0.217513 seconds.
# process image 290
# Load Image: 0.007169 seconds.
# Inference time:  0.00455784797668457
# Prediction: 0.090397 seconds.
# process image 291
# Load Image: 0.007691 seconds.
# Inference time:  0.04542803764343262
# Prediction: 0.082194 seconds.
# process image 292
# Load Image: 0.003927 seconds.
# Inference time:  0.10038065910339355
# Prediction: 0.175069 seconds.
# process image 293
# Load Image: 0.008665 seconds.
# Inference time:  0.01374053955078125
# Prediction: 0.224856 seconds.
# process image 294
# Load Image: 0.004399 seconds.
# Inference time:  0.004933357238769531
# Prediction: 0.060976 seconds.
# process image 295
# Load Image: 0.005078 seconds.
# Inference time:  0.014057397842407227
# Prediction: 0.206158 seconds.
# process image 296
# Load Image: 0.004251 seconds.
# Inference time:  0.060066938400268555
# Prediction: 0.108014 seconds.
# process image 297
# Load Image: 0.004378 seconds.
# Inference time:  0.0966942310333252
# Prediction: 0.175171 seconds.
# process image 298
# Load Image: 0.006994 seconds.
# Inference time:  0.07282733917236328
# Prediction: 0.100715 seconds.
# process image 299
# Load Image: 0.004267 seconds.
# Inference time:  0.0895845890045166
# Prediction: 0.199566 seconds.
# process image 300
# Load Image: 0.006146 seconds.
# Inference time:  0.09281253814697266
# Prediction: 0.198064 seconds.
# process image 301
# Load Image: 0.007596 seconds.
# Inference time:  0.008693456649780273
# Prediction: 0.081081 seconds.
# process image 302
# Load Image: 0.069426 seconds.
# Inference time:  0.008948802947998047
# Prediction: 0.106699 seconds.
# process image 303
# Load Image: 0.004974 seconds.
# Inference time:  0.07962870597839355
# Prediction: 0.101873 seconds.
# process image 304
# Load Image: 0.004668 seconds.
# Inference time:  0.009479284286499023
# Prediction: 0.216831 seconds.
# process image 305
# Load Image: 0.003764 seconds.
# Inference time:  0.004072666168212891
# Prediction: 0.074562 seconds.
# process image 306
# Load Image: 0.005353 seconds.
# Inference time:  0.012052059173583984
# Prediction: 0.190392 seconds.
# process image 307
# Load Image: 0.009301 seconds.
# Inference time:  0.0050008296966552734
# Prediction: 0.077328 seconds.
# process image 308
# Load Image: 0.011194 seconds.
# Inference time:  0.09299206733703613
# Prediction: 0.109499 seconds.
# process image 309
# Load Image: 0.009490 seconds.
# Inference time:  0.012545108795166016
# Prediction: 0.180054 seconds.
# process image 310
# Load Image: 0.014175 seconds.
# Inference time:  0.006030082702636719
# Prediction: 0.105825 seconds.
# process image 311
# Load Image: 0.005786 seconds.
# Inference time:  0.008532285690307617
# Prediction: 0.188909 seconds.
# process image 312
# Load Image: 0.005796 seconds.
# Inference time:  0.004416704177856445
# Prediction: 0.074817 seconds.
# process image 313
# Load Image: 0.005520 seconds.
# Inference time:  0.013335466384887695
# Prediction: 0.189162 seconds.
# process image 314
# Load Image: 0.009459 seconds.
# Inference time:  0.07683730125427246
# Prediction: 0.135111 seconds.
# process image 315
# Load Image: 0.003465 seconds.
# Inference time:  0.004895448684692383
# Prediction: 0.157970 seconds.
# process image 316
# Load Image: 0.005457 seconds.
# Inference time:  0.07064366340637207
# Prediction: 0.092431 seconds.
# process image 317
# Load Image: 0.007473 seconds.
# Inference time:  0.01311945915222168
# Prediction: 0.210470 seconds.
# process image 318
# Load Image: 0.005344 seconds.
# Inference time:  0.005027294158935547
# Prediction: 0.065149 seconds.
# process image 319
# Load Image: 0.005047 seconds.
# Inference time:  0.005181074142456055
# Prediction: 0.117764 seconds.
# process image 320
# Load Image: 0.072340 seconds.
# Inference time:  0.09637784957885742
# Prediction: 0.122300 seconds.
# process image 321
# Load Image: 0.005964 seconds.
# Inference time:  0.07771992683410645
# Prediction: 0.117801 seconds.
# process image 322
# Load Image: 0.006085 seconds.
# Inference time:  0.008133649826049805
# Prediction: 0.189609 seconds.
# process image 323
# Load Image: 0.005243 seconds.
# Inference time:  0.006517648696899414
# Prediction: 0.068323 seconds.
# process image 324
# Load Image: 0.089360 seconds.
# Inference time:  0.08356165885925293
# Prediction: 0.132523 seconds.
# process image 325
# Load Image: 0.011799 seconds.
# Inference time:  0.043915748596191406
# Prediction: 0.086302 seconds.
# process image 326
# Load Image: 0.004225 seconds.
# Inference time:  0.006686210632324219
# Prediction: 0.172196 seconds.
# process image 327
# Load Image: 0.083969 seconds.
# Inference time:  0.013781070709228516
# Prediction: 0.025342 seconds.
# process image 328
# Load Image: 0.072224 seconds.
# Inference time:  0.008905887603759766
# Prediction: 0.117200 seconds.
# process image 329
# Load Image: 0.006753 seconds.
# Inference time:  0.07828354835510254
# Prediction: 0.099555 seconds.
# process image 330
# Load Image: 0.007835 seconds.
# Inference time:  0.009119510650634766
# Prediction: 0.218028 seconds.
# process image 331
# Load Image: 0.004954 seconds.
# Inference time:  0.032561540603637695
# Prediction: 0.060941 seconds.
# process image 332
# Load Image: 0.005448 seconds.
# Inference time:  0.09845519065856934
# Prediction: 0.206080 seconds.
# process image 333
# Load Image: 0.006081 seconds.
# Inference time:  0.0064792633056640625
# Prediction: 0.086660 seconds.
# process image 334
# Load Image: 0.003959 seconds.
# Prediction: 0.100859 seconds.
# process image 362
# Load Image: 0.010092 seconds.
# Inference time:  0.007232189178466797
# Prediction: 0.077581 seconds.
# process image 363
# Load Image: 0.086836 seconds.
# Inference time:  0.0944375991821289
# Prediction: 0.131759 seconds.
# process image 364
# Load Image: 0.012171 seconds.
# Inference time:  0.010731935501098633
# Prediction: 0.152354 seconds.
# process image 365
# Load Image: 0.013816 seconds.
# Inference time:  0.009199142456054688
# Prediction: 0.122535 seconds.
# process image 366
# Load Image: 0.007192 seconds.
# Inference time:  0.09589934349060059
# Prediction: 0.164856 seconds.
# process image 367
# Load Image: 0.012819 seconds.
# Inference time:  0.08003711700439453
# Prediction: 0.092794 seconds.
# process image 368
# Load Image: 0.009802 seconds.
# Inference time:  0.011129379272460938
# Prediction: 0.190755 seconds.
# process image 369
# Load Image: 0.007219 seconds.
# Inference time:  0.0047299861907958984
# Prediction: 0.097194 seconds.
# process image 370
# Load Image: 0.009204 seconds.
# Inference time:  0.008932352066040039
# Prediction: 0.210093 seconds.
# process image 371
# Load Image: 0.005524 seconds.
# Inference time:  0.00443577766418457
# Prediction: 0.070896 seconds.
# process image 372
# Load Image: 0.001998 seconds.
# Inference time:  0.00426483154296875
# Prediction: 0.078319 seconds.
# process image 373
# Load Image: 0.007138 seconds.
# Inference time:  0.013725042343139648
# Prediction: 0.220649 seconds.
# process image 374
# Load Image: 0.005727 seconds.
# Inference time:  0.05537748336791992
# Prediction: 0.088222 seconds.
# process image 375
# Load Image: 0.002490 seconds.
# Inference time:  0.06775975227355957
# Prediction: 0.098485 seconds.
# process image 376
# Load Image: 0.004894 seconds.
# Inference time:  0.011169195175170898
# Prediction: 0.188571 seconds.
# process image 377
# Load Image: 0.007575 seconds.
# Inference time:  0.0064504146575927734
# Prediction: 0.084633 seconds.
# process image 378
# Load Image: 0.007974 seconds.
# Inference time:  0.016752004623413086
# Prediction: 0.124310 seconds.
# process image 379
# Load Image: 0.004357 seconds.
# Inference time:  0.09261274337768555
# Prediction: 0.189563 seconds.
# process image 380
# Load Image: 0.004804 seconds.
# Inference time:  0.012661457061767578
# Prediction: 0.169205 seconds.
# process image 381
# Load Image: 0.008414 seconds.
# Inference time:  0.0128021240234375
# Prediction: 0.185806 seconds.
# process image 382
# Load Image: 0.008147 seconds.
# Inference time:  0.005178213119506836
# Prediction: 0.094926 seconds.
# process image 383
# Load Image: 0.006195 seconds.
# Inference time:  0.007782936096191406
# Prediction: 0.207698 seconds.
# process image 384
# Load Image: 0.006498 seconds.
# Inference time:  0.0063304901123046875
# Prediction: 0.169035 seconds.
# process image 385
# Load Image: 0.007167 seconds.
# Inference time:  0.07430624961853027
# Prediction: 0.087692 seconds.
# process image 386
# Load Image: 0.011812 seconds.
# Inference time:  0.01254892349243164
# Prediction: 0.218606 seconds.
# process image 387
# Load Image: 0.004886 seconds.
# Inference time:  0.05772566795349121
# Prediction: 0.084397 seconds.
# process image 388
# Load Image: 0.007407 seconds.
# Inference time:  0.012302637100219727
# Prediction: 0.182611 seconds.
# process image 389
# Load Image: 0.006801 seconds.
# Inference time:  0.06846761703491211
# Prediction: 0.103812 seconds.
# process image 390
# Load Image: 0.005836 seconds.
# Inference time:  0.011785745620727539
# Prediction: 0.181597 seconds.
# process image 391
# Load Image: 0.009107 seconds.
# Inference time:  0.00814056396484375
# Prediction: 0.087056 seconds.
# process image 392
# Load Image: 0.004949 seconds.
# Inference time:  0.09337544441223145
# Prediction: 0.199207 seconds.
# process image 393
# Load Image: 0.006402 seconds.
# Inference time:  0.004651784896850586
# Prediction: 0.102534 seconds.
# process image 394
# Load Image: 0.004678 seconds.
# Inference time:  0.0118560791015625
# Prediction: 0.195501 seconds.
# process image 395
# Load Image: 0.005396 seconds.
# Inference time:  0.005787372589111328
# Prediction: 0.083077 seconds.
# process image 396
# Load Image: 0.008560 seconds.
# Inference time:  0.013642549514770508
# Prediction: 0.206024 seconds.
# process image 397
# Load Image: 0.005124 seconds.
# Inference time:  0.04800581932067871
# Prediction: 0.069874 seconds.
# process image 398
# Load Image: 0.004015 seconds.
# Inference time:  0.08964085578918457
# Prediction: 0.187423 seconds.
# process image 399
# Load Image: 0.009914 seconds.
# Inference time:  0.00825047492980957
# Prediction: 0.100553 seconds.
# process image 400
# Load Image: 0.005744 seconds.
# Inference time:  0.006822347640991211
# Prediction: 0.193004 seconds.
# process image 401
# Load Image: 0.007507 seconds.
# Inference time:  0.005190134048461914
# Prediction: 0.098125 seconds.
# process image 402
# Load Image: 0.078484 seconds.
# Inference time:  0.10029792785644531
# Prediction: 0.145863 seconds.
# process image 403
# Load Image: 0.010204 seconds.
# Inference time:  0.012141704559326172
# Prediction: 0.177875 seconds.
# process image 404
# Load Image: 0.006907 seconds.
# Inference time:  0.0045964717864990234
# Prediction: 0.056034 seconds.
# process image 405
# Load Image: 0.005612 seconds.
# Inference time:  0.009555578231811523
# Prediction: 0.234164 seconds.
# process image 406
# Load Image: 0.005074 seconds.
# Inference time:  0.04354381561279297
# Prediction: 0.068085 seconds.
# process image 407
# Load Image: 0.006653 seconds.
# Inference time:  0.011678934097290039
# Prediction: 0.209950 seconds.
# process image 408
# Load Image: 0.004001 seconds.
# Inference time:  0.004194736480712891
# Prediction: 0.061627 seconds.
# process image 409
# Load Image: 0.013265 seconds.
# Inference time:  0.008774518966674805
# Prediction: 0.188149 seconds.
# process image 410
# Load Image: 0.007127 seconds.
# Inference time:  0.08413171768188477
# Prediction: 0.107855 seconds.
# process image 411
# Load Image: 0.007153 seconds.
# Inference time:  0.09431004524230957
# Prediction: 0.204593 seconds.
# process image 412
# Load Image: 0.004902 seconds.
# Inference time:  0.006510496139526367
# Prediction: 0.107906 seconds.
# process image 413
# Load Image: 0.007064 seconds.
# ...
# Load Image: 0.091018 seconds.
# Inference time:  0.08960294723510742
# Prediction: 0.120935 seconds.
# process image 5692
# Load Image: 0.007906 seconds.
# Inference time:  0.0687856674194336
# Prediction: 0.109950 seconds.
# process image 5693
# Load Image: 0.002694 seconds.
# Inference time:  0.0049533843994140625
# Prediction: 0.090228 seconds.
# process image 5694
# Load Image: 0.004178 seconds.
# Inference time:  0.009675264358520508
# Prediction: 0.215587 seconds.
# process image 5695
# Load Image: 0.004065 seconds.
# Inference time:  0.03639817237854004
# Prediction: 0.060219 seconds.
# process image 5696
# Load Image: 0.005369 seconds.
# Inference time:  0.016021013259887695
# Prediction: 0.189727 seconds.
# process image 5697
# Load Image: 0.008810 seconds.
# Inference time:  0.06742525100708008
# Prediction: 0.120312 seconds.
# process image 5698
# Load Image: 0.004577 seconds.
# Inference time:  0.09963417053222656
# Prediction: 0.189531 seconds.
# process image 5699
# Load Image: 0.004468 seconds.
# Inference time:  0.0570831298828125
# Prediction: 0.072899 seconds.
# process image 5700
# Load Image: 0.010323 seconds.
# Inference time:  0.013277769088745117
# Prediction: 0.210124 seconds.
# process image 5701
# Load Image: 0.009069 seconds.
# Inference time:  0.04227256774902344
# Prediction: 0.082902 seconds.
# process image 5702
# Load Image: 0.004538 seconds.
# Inference time:  0.09531235694885254
# Prediction: 0.167844 seconds.
# process image 5703
# Load Image: 0.013806 seconds.
# Inference time:  0.006922721862792969
# Prediction: 0.101537 seconds.
# process image 5704
# Load Image: 0.006206 seconds.
# Inference time:  0.09604620933532715
# Prediction: 0.222685 seconds.
# process image 5705
# Load Image: 0.005070 seconds.
# Inference time:  0.03534078598022461
# Prediction: 0.063231 seconds.
# process image 5706
# Load Image: 0.082388 seconds.
# Inference time:  0.00936126708984375
# Prediction: 0.110338 seconds.
# process image 5707
# Load Image: 0.009610 seconds.
# Inference time:  0.006005525588989258
# Prediction: 0.099732 seconds.
# process image 5708
# Load Image: 0.003752 seconds.
# Inference time:  0.09201741218566895
# Prediction: 0.216879 seconds.
# process image 5709
# Load Image: 0.005671 seconds.
# Inference time:  0.006752729415893555
# Prediction: 0.174437 seconds.
# process image 5710
# Load Image: 0.006659 seconds.
# Inference time:  0.05414271354675293
# Prediction: 0.104363 seconds.
# process image 5711
# Load Image: 0.004617 seconds.
# Inference time:  0.007691860198974609
# Prediction: 0.160086 seconds.
# process image 5712
# Load Image: 0.007124 seconds.
# Inference time:  0.009788751602172852
# Prediction: 0.104499 seconds.
# process image 5713
# Load Image: 0.091064 seconds.
# Inference time:  0.008131265640258789
# Prediction: 0.103186 seconds.
# process image 5714
# Load Image: 0.013728 seconds.
# Inference time:  0.07034111022949219
# Prediction: 0.090717 seconds.
# process image 5715
# Load Image: 0.078453 seconds.
# Inference time:  0.010196685791015625
# Prediction: 0.125342 seconds.
# process image 5716
# Load Image: 0.005923 seconds.
# Inference time:  0.005228519439697266
# Prediction: 0.073833 seconds.
# process image 5717
# Load Image: 0.011730 seconds.
# Inference time:  0.012022733688354492
# Prediction: 0.222131 seconds.
# process image 5718
# Load Image: 0.004320 seconds.
# Inference time:  0.0048367977142333984
# Prediction: 0.060495 seconds.
# process image 5719
# Load Image: 0.007840 seconds.
# Inference time:  0.005673885345458984
# Prediction: 0.224070 seconds.
# process image 5720
# Load Image: 0.005790 seconds.
# Inference time:  0.047568321228027344
# Prediction: 0.062436 seconds.
# process image 5721
# Load Image: 0.005435 seconds.
# Inference time:  0.010476112365722656
# Prediction: 0.204822 seconds.
# process image 5722
# Load Image: 0.006724 seconds.
# Inference time:  0.06566309928894043
# Prediction: 0.132644 seconds.
# process image 5723
# Load Image: 0.002399 seconds.
# Inference time:  0.033690690994262695
# Prediction: 0.056556 seconds.
# process image 5724
# Load Image: 0.005332 seconds.
# Inference time:  0.09311389923095703
# Prediction: 0.181668 seconds.
# process image 5725
# Load Image: 0.008868 seconds.
# Inference time:  0.07970690727233887
# Prediction: 0.111933 seconds.
# process image 5726
# Load Image: 0.004582 seconds.
# Inference time:  0.007861137390136719
# Prediction: 0.166515 seconds.
# process image 5727
# Load Image: 0.006442 seconds.
# Inference time:  0.009109735488891602
# Prediction: 0.103343 seconds.
# process image 5728
# Load Image: 0.005192 seconds.
# Inference time:  0.09778785705566406
# Prediction: 0.224102 seconds.
# process image 5729
# Load Image: 0.004911 seconds.
# Inference time:  0.016173601150512695
# Prediction: 0.158674 seconds.
# process image 5730
# Load Image: 0.012280 seconds.
# Inference time:  0.007954120635986328
# Prediction: 0.124271 seconds.
# process image 5731
# Load Image: 0.006616 seconds.
# Inference time:  0.008426666259765625
# Prediction: 0.166938 seconds.
# process image 5732
# Load Image: 0.005437 seconds.
# Inference time:  0.011335372924804688
# Prediction: 0.088674 seconds.
# process image 5733
# Load Image: 0.006252 seconds.
# Inference time:  0.012585878372192383
# Prediction: 0.196103 seconds.
# process image 5734
# Load Image: 0.006856 seconds.
# Inference time:  0.007857561111450195
# Prediction: 0.108755 seconds.
# process image 5735
# Load Image: 0.003631 seconds.
# Inference time:  0.09409379959106445
# Prediction: 0.180142 seconds.
# process image 5736
# Load Image: 0.009211 seconds.
# Inference time:  0.09550619125366211
# Prediction: 0.218622 seconds.
# process image 5737
# Load Image: 0.003551 seconds.
# Inference time:  0.0055866241455078125
# Prediction: 0.073321 seconds.
# process image 5738
# Load Image: 0.004194 seconds.
# Inference time:  0.005820512771606445
# Prediction: 0.173286 seconds.
# process image 5739
# Load Image: 0.008731 seconds.
# Inference time:  0.07827472686767578
# Prediction: 0.094018 seconds.
# process image 5740
# Load Image: 0.005985 seconds.
# Inference time:  0.09581208229064941
# Prediction: 0.209029 seconds.
# process image 5741
# Load Image: 0.014155 seconds.
# Inference time:  0.09490609169006348
# Prediction: 0.176463 seconds.
# process image 5742
# Load Image: 0.010456 seconds.
# Inference time:  0.015522956848144531
# Prediction: 0.209960 seconds.
# process image 5743
# Load Image: 0.004432 seconds.
# Inference time:  0.05017828941345215
# Prediction: 0.074353 seconds.
# process image 5744
# Load Image: 0.005890 seconds.
# Inference time:  0.012022018432617188
# Prediction: 0.096770 seconds.
# process image 5745
# Load Image: 0.078138 seconds.
# Inference time:  0.09340691566467285
# Prediction: 0.146301 seconds.
# process image 5746
# Load Image: 0.004104 seconds.
# Inference time:  0.048296213150024414
# Prediction: 0.100352 seconds.
# process image 5747
# Load Image: 0.004771 seconds.
# Inference time:  0.013645648956298828
# Prediction: 0.184281 seconds.
# process image 5748
# Load Image: 0.058199 seconds.
# Inference time:  0.006479978561401367
# Prediction: 0.132620 seconds.
# process image 5749
# Load Image: 0.005400 seconds.
# Inference time:  0.09599113464355469
# Prediction: 0.202058 seconds.
# process image 5750
# Load Image: 0.005024 seconds.
# Inference time:  0.047962188720703125
# Prediction: 0.080708 seconds.
# process image 5751
# Load Image: 0.004724 seconds.
# Inference time:  0.006749629974365234
# Prediction: 0.175185 seconds.
# process image 5752
# Load Image: 0.006113 seconds.
# Inference time:  0.006449222564697266
# Prediction: 0.109141 seconds.
# process image 5753
# Load Image: 0.003712 seconds.
# Inference time:  0.008076667785644531
# Prediction: 0.219677 seconds.
# process image 5754
# Load Image: 0.003316 seconds.
# Inference time:  0.0063440799713134766
# Prediction: 0.164360 seconds.
# process image 5755
# Load Image: 0.011345 seconds.
# Inference time:  0.005501985549926758
# Prediction: 0.094143 seconds.
# process image 5756
# Load Image: 0.006104 seconds.
# Inference time:  0.006346940994262695
# Prediction: 0.202323 seconds.
# process image 5757
# Load Image: 0.006291 seconds.
# Inference time:  0.00500941276550293
# Prediction: 0.063690 seconds.
# process image 5758
# Load Image: 0.009272 seconds.
# Inference time:  0.008509159088134766
# Prediction: 0.189723 seconds.
# process image 5759
# Load Image: 0.009421 seconds.
# Inference time:  0.0067784786224365234
# Prediction: 0.085133 seconds.
# process image 5760
# Load Image: 0.007843 seconds.
# Inference time:  0.01376652717590332
# Prediction: 0.195383 seconds.
# process image 5761
# Load Image: 0.011069 seconds.
# Inference time:  0.08373427391052246
# Prediction: 0.128325 seconds.
# process image 5762
# Load Image: 0.005420 seconds.
# Inference time:  0.005549430847167969
# Prediction: 0.068876 seconds.
# process image 5763
# Load Image: 0.085521 seconds.
# Inference time:  0.005415678024291992
# Prediction: 0.108785 seconds.
# process image 5764
# Load Image: 0.007965 seconds.
# Inference time:  0.00420379638671875
# Prediction: 0.085871 seconds.
# process image 5765
# Load Image: 0.088305 seconds.
# Inference time:  0.011274337768554688
# Prediction: 0.110202 seconds.
# process image 5766
# Load Image: 0.013291 seconds.
# Inference time:  0.010326623916625977
# Prediction: 0.111813 seconds.
# process image 5767
# Load Image: 0.004236 seconds.
# Inference time:  0.008545160293579102
# Prediction: 0.160575 seconds.
# process image 5768
# Load Image: 0.011506 seconds.
# Inference time:  0.005990505218505859
# Prediction: 0.114658 seconds.
# process image 5769
# Load Image: 0.008919 seconds.
# Inference time:  0.0047457218170166016
# Prediction: 0.076407 seconds.
# process image 5770
# Load Image: 0.085183 seconds.
# Inference time:  0.09937119483947754
# Prediction: 0.129395 seconds.
# process image 5771
# Load Image: 0.004349 seconds.
# Inference time:  0.008617639541625977
# Prediction: 0.164823 seconds.
# process image 5772
# Load Image: 0.011887 seconds.
# Inference time:  0.08409857749938965
# Prediction: 0.116634 seconds.
# process image 5773
# Load Image: 0.004452 seconds.
# Inference time:  0.009130716323852539
# Prediction: 0.081755 seconds.
# process image 5774
# Load Image: 0.090456 seconds.
# Inference time:  0.008863687515258789
# Prediction: 0.111156 seconds.
# process image 5775
# Load Image: 0.008108 seconds.
# Inference time:  0.009816408157348633
# Prediction: 0.192975 seconds.
# process image 5776
# Load Image: 0.009703 seconds.
# Inference time:  0.0683286190032959
# Prediction: 0.122778 seconds.
# process image 5777
# Load Image: 0.004917 seconds.
# Inference time:  0.09490346908569336
# Prediction: 0.169884 seconds.
# process image 5778
# Load Image: 0.007156 seconds.
# Inference time:  0.004595041275024414
# Prediction: 0.081952 seconds.
# process image 5779
# Load Image: 0.007741 seconds.
# Inference time:  0.005120038986206055
# Prediction: 0.195631 seconds.
# process image 5780
# Load Image: 0.006502 seconds.
# Inference time:  0.05981802940368652
# Prediction: 0.091103 seconds.
# process image 5781
# Load Image: 0.006660 seconds.
# Inference time:  0.007180452346801758
# Prediction: 0.097363 seconds.
# process image 5782
# Load Image: 0.005771 seconds.
# Inference time:  0.09501242637634277
# Prediction: 0.212650 seconds.
# process image 5783
# Load Image: 0.006416 seconds.
# Inference time:  0.005154132843017578
# Prediction: 0.152653 seconds.
# process image 5784
# Load Image: 0.004158 seconds.
# Inference time:  0.005699634552001953
# Prediction: 0.018343 seconds.
# process image 5785
# Load Image: 0.003913 seconds.
# Inference time:  0.08946347236633301
# Prediction: 0.169154 seconds.
# process image 5786
# Load Image: 0.010840 seconds.
# Inference time:  0.00719451904296875
# Prediction: 0.221249 seconds.
# process image 5787
# Load Image: 0.005353 seconds.
# Inference time:  0.050348520278930664
# Prediction: 0.059449 seconds.
# process image 5788
# Load Image: 0.010718 seconds.
# Inference time:  0.012451410293579102
# Prediction: 0.208855 seconds.
# process image 5789
# Load Image: 0.007026 seconds.
# Inference time:  0.004727840423583984
# Prediction: 0.099347 seconds.
# process image 5790
# Load Image: 0.004475 seconds.
# Inference time:  0.011230707168579102
# Prediction: 0.166056 seconds.
# process image 5791
# Load Image: 0.011321 seconds.
# Inference time:  0.008264303207397461
# Prediction: 0.129059 seconds.
# process image 5792
# Load Image: 0.006145 seconds.
# Inference time:  0.00643610954284668
# Prediction: 0.177185 seconds.
# process image 5793
# Load Image: 0.006812 seconds.
# Inference time:  0.005172014236450195
# Prediction: 0.080556 seconds.
# process image 5794
# Load Image: 0.003120 seconds.
# Inference time:  0.0050737857818603516
# Prediction: 0.094207 seconds.
# process image 5795
# Load Image: 0.006509 seconds.
# Inference time:  0.08041095733642578
# Prediction: 0.110253 seconds.
# process image 5796
# Load Image: 0.068210 seconds.
# Inference time:  0.010377645492553711
# Prediction: 0.135203 seconds.
# process image 5797
# Load Image: 0.005831 seconds.
# Inference time:  0.004965305328369141
# Prediction: 0.074051 seconds.
# process image 5798
# Load Image: 0.005199 seconds.
# Inference time:  0.007192134857177734
# Prediction: 0.194406 seconds.
# process image 5799
# Load Image: 0.005477 seconds.
# Inference time:  0.07428288459777832
# Prediction: 0.101884 seconds.
# process image 5800
# Load Image: 0.074138 seconds.
# Inference time:  0.0065155029296875
# Prediction: 0.113514 seconds.
# process image 5801
# Load Image: 0.010383 seconds.
# Inference time:  0.005148172378540039
# Prediction: 0.088788 seconds.
# process image 5802
# Load Image: 0.008126 seconds.
# Inference time:  0.0985257625579834
# Prediction: 0.223027 seconds.
# process image 5803
# Load Image: 0.005516 seconds.
# Inference time:  0.004913806915283203
# Prediction: 0.080746 seconds.
# process image 5804
# Load Image: 0.005957 seconds.
# Inference time:  0.09307742118835449
# Prediction: 0.202954 seconds.
# process image 5805
# Load Image: 0.004047 seconds.
# Inference time:  0.006730318069458008
# Prediction: 0.068364 seconds.
# process image 5806
# Load Image: 0.005669 seconds.
# Inference time:  0.010801076889038086
# Prediction: 0.178684 seconds.
# process image 5807
# Load Image: 0.014163 seconds.
# Inference time:  0.07922959327697754
# Prediction: 0.122963 seconds.
# process image 5808
# Load Image: 0.004784 seconds.
# Inference time:  0.008577108383178711
# Prediction: 0.074449 seconds.
# process image 5809
# Load Image: 0.091938 seconds.
# Inference time:  0.09090590476989746
# Prediction: 0.116502 seconds.
# process image 5810
# Load Image: 0.006752 seconds.
# Inference time:  0.011097192764282227
# Prediction: 0.201445 seconds.
# process image 5811
# Load Image: 0.005364 seconds.
# Inference time:  0.055777549743652344
# Prediction: 0.081867 seconds.
# process image 5812
# Load Image: 0.004386 seconds.
# Inference time:  0.007954120635986328
# Prediction: 0.185462 seconds.
# process image 5813
# Load Image: 0.007410 seconds.
# Inference time:  0.06989049911499023
# Prediction: 0.110358 seconds.
# process image 5814
# Load Image: 0.004341 seconds.
# Inference time:  0.010345458984375
# Prediction: 0.079295 seconds.
# process image 5815
# Load Image: 0.015003 seconds.
# Inference time:  0.07805132865905762
# Prediction: 0.113061 seconds.
# process image 5816
# Load Image: 0.005346 seconds.
# Inference time:  0.013074636459350586
# Prediction: 0.197815 seconds.
# process image 5817
# Load Image: 0.007260 seconds.
# Inference time:  0.06297969818115234
# Prediction: 0.119696 seconds.
# process image 5818
# Load Image: 0.005566 seconds.
# Inference time:  0.005498647689819336
# Prediction: 0.139262 seconds.
# process image 5819
# Load Image: 0.008402 seconds.
# Inference time:  0.0815584659576416
# Prediction: 0.121194 seconds.
# process image 5820
# Load Image: 0.004948 seconds.
# Inference time:  0.00652313232421875
# Prediction: 0.158276 seconds.
# process image 5821
# Load Image: 0.010801 seconds.
# Inference time:  0.08127188682556152
# Prediction: 0.104085 seconds.
# process image 5822
# Load Image: 0.007979 seconds.
# Inference time:  0.012550830841064453
# Prediction: 0.182587 seconds.
#
#
# Average Precision Per-class:
# aeroplane: 0.9065724815724817
# bicycle: 0.9029957450484893
# bird: 0.886672274310304
# boat: 0.8310207986197913
# bottle: 0.7304030684063941
# bus: 0.867888083993603
# car: 0.8483826841997166
# cat: 0.9090909090909093
# chair: 0.8227586241650934
# cow: 0.8931188623457623
# diningtable: 0.8510264572368926
# dog: 0.9057704375697931
# horse: 0.9062799476592582
# motorbike: 0.9068803536888645
# person: 0.8723944464823337
# pottedplant: 0.7629605735552946
# sheep: 0.8602529471616469
# sofa: 0.9018204018204019
# train: 0.907828282828283
# tvmonitor: 0.8993702781768167
#
# Average Precision Across All Classes:0.8686743828966066
